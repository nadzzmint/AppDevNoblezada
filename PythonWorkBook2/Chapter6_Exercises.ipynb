# %% [markdown]
# ###EXERCISE 1

# %% [markdown]
# What will the following expressions produce?
#
# text[4]
#
# text[2:4]
#
# text[:4]
#
# text[4:]
#
# text[-2]
#
# text[-4:-2]
#
# text[-2:]
#
# text[:-2]

# %%
text = "Business Analytics"
print(text[4])
print(text[2:4])
print(text[4:])
print(text[:4])
print(text[-2])
print(text[-4:-2])
print(text[-2:])
print(text[:-2])
# Out:
# n
# si
# ness Analytics
# Busi
# c
# ti
# cs
# Business Analyti

# %% [markdown]
# ###EXERCISE 2

# %% [markdown]
# What string slicing expression gives out the following words:
#
# 'One '
#
# 'Ring'
#
# 'all'
#
# 'them'
#
# 'One Ring to rule them all'

# %%
phrase = "One ring to rule them all"
print(phrase[:4])
print(phrase[4:8])
print(phrase[-3:])
print(phrase[17:-4])
print(phrase[:])
# Out:
# One
# ring
# all
# them
# One ring to rule them all

# %% [markdown]
# ###CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a full name, then does the following:
#
# strips the name of any trailing spaces capitalizes the first letter puts the rest into smaller letters

# %%
for i in range(10) :
  name = input("Enter your full name: ")
  if name == "exit" :
      break
  print(name.strip().capitalize())
# Out:
# Enter your full name: Shane
# Shane
# Enter your full name: nadynn
# Nadynn
# Enter your full name: exit
