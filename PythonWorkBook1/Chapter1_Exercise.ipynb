# %% [markdown]
# CHAPTER 1

# %% [markdown]
# ###Exercise 1
# EXERCISE 1-Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
print('Hello world!') # The Big letter p in print is trhe error.
# Out:
# Hello world!

# %%
print('Hello world!') #lack of single quotation
# Out:
# Hello world!

# %%
print('Hello world!') # no quotation mark at the end
# Out:
# Hello world!

# %%
print('Hello world!') # too much quotation
# Out:
# Hello world!

# %% [markdown]
# ###Exercise 2
# Exercise 2

# %%
x = 43
x = x + 1
print(x) #no error

# %% [markdown]
# ###Exercise 3
# Exercise 3

# %%
x = 43
x = x + 1
print(x) #the variable x is big letter
